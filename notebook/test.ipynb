# %%
import pandas as pd
import sqlalchemy as sa

column_names = [
    'id',
    'type',
    'datetime',
    'date',
    'server',
    'ipAddress',
    'ipProxy',
    'country',
    'language',
    'searchType',
    'programType',
    'adType',
    'adDisplayType',
    'idFeed',
    'idAdvertiser',
    'idCampaign',
    'idGroup',
    'idAd',
    'idPublisher',
    'idSite',
    'idChannel',
    'idDomain',
    'idGroupSite',
    'idGroupSiteChannel',
    'position',
    'keywords',
    'freeKeywords',
    'destinationUrl',
    'refererUrl',
    'userAgent',
    'browser',
    'status',
    'fraudCause',
    'spent',
    'adminRevenue',
    'pubRevenue',
    'idSearchType',
    'idConversion',
    'conversionValue',
    'idCategory',
    'capping',
    'budget',
    'displayUrl',
    'misc1',
    'misc2',
    'misc3',
    'vars',
    'subId',
    'deviceType',
    'os',
    'vendor',
    'device',
    'carrier',
    'idGroupChannelType',
    'ns',
    'httpReferer',
    'source'
]

if __name__ == "__main__":
    df_s = pd.read_csv("input/2020-06-08/stats_423_202006082130EDT.log.bz2", compression='bz2',sep='\t',dtype='unicode',header=None,names=column_names)
#     create_table('test', 'clickhouse://default@192.168.0.155:8123/default')
#     store_to_ch(df_s, 'test', 'clickhouse://default@192.168.0.155:8123/default')
    
    
#     ph.to_clickhouse(df_s, 'test', index=False, chunksize=100000, connection={'host': 'http://192.168.0.155:8123/','database': 'default', 'password': ''})
#     df_s.to_sql("table", con = engine, if_exists='append', index = False)
    print(df_s.head())
# Out:
#                                                   id type    datetime  \
# 0  1884b31c-a3c2-4fa6-87e8-d8a8cd801967:0f756838-...  imp  1591666200
# 1  bb769784-94a8-4e37-9143-8cdea34f9117:bd38ad30-...  imp  1591666200
# 2  8274a88a-b07f-4867-a8ca-7b6ae4b16ae4:360dbac8-...  imp  1591666200
# 3  6872426c-d1e6-4bb5-a226-906923eae966:334aa1c7-...  imp  1591666200
# 4  ddd50b0f-09c0-450c-bfe1-2846df4fb0af:b69fdc4a-...  imp  1591666200
#
#          date server       ipAddress       ipProxy country language  \
# 0  2020-06-08    423  223.104.63.229           NaN      CN       ZH
# 1  2020-06-08    423   91.129.97.115           NaN      EE       RU
# 2  2020-06-08    423    24.3.111.249           NaN      US       EN
# 3  2020-06-08    423   91.129.97.115           NaN      EE       RU
# 4  2020-06-08    423   39.128.51.173  10.118.33.30      CN       ZH
#
#   searchType  ... subId deviceType       os   vendor               device  \
# ...
