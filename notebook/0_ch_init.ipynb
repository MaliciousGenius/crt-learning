# %%
# import sqlalchemy as sa
import sqlalchemy as sa

def execute_sql(sql):
    engine = sa.create_engine('clickhouse://default@192.168.0.155:8123/default', encoding='utf8')
#     with engine.connect() as connect:
#         result = connect.execute(sql)
#     return
    connect = engine.connect()
    try:
        connect.execute(sql)
    finally:
        connect.close()
    return

def create_table():
    sql = '''
        create table events (
            id String,
            type String,
            datetime String,
            date String,
            server String,
            ipAddress String,
            ipProxy String,
            country String,
            language String,
            searchType String,
            programType String,
            adType String,
            adDisplayType String,
            idFeed String,
            idAdvertiser String,
            idCampaign String,
            idGroup String,
            idAd String,
            idPublisher String,
            idSite String,
            idChannel String,
            idDomain String,
            idGroupSite String,
            idGroupSiteChannel String,
            position String,
            keywords String,
            freeKeywords String,
            destinationUrl String,
            refererUrl String,
            userAgent String,
            browser String,
            status String,
            fraudCause String,
            spent String,
            adminRevenue String,
            pubRevenue String,
            idSearchType String,
            idConversion String,
            conversionValue String,
            idCategory String,
            capping String,
            budget String,
            displayUrl String,
            misc1 String,
            misc2 String,
            misc3 String,
            vars String,
            subId String,
            deviceType String,
            os String,
            vendor String,
            device String,
            carrier String,
            idGroupChannelType String,
            ns String,
            httpReferer String,
            source String
        ) ENGINE = MergeTree
        Order by id
    '''
    execute_sql(sql)
        
        
if __name__ == "__main__":
    create_table()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/infi/clickhouse_orm/database.py in select(self, query, model_class, settings)
#     274         lines = r.iter_lines()
# --> 275         field_names = parse_tsv(next(lines))
#     276         field_types = parse_tsv(next(lines))
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-67121df52ba3> in <module>
#      81
#      82 if __name__ == "__main__":
# ---> 83     create_table()
#
# <ipython-input-1-67121df52ba3> in create_table()
#      77         Order by id
#      78     '''
# ---> 79     execute_sql(sql)
#      80
#      81
#
# <ipython-input-1-67121df52ba3> in execute_sql(sql)
#       9     connect = engine.connect()
#      10     try:
# ---> 11         connect.execute(sql)
#      12     finally:
#      13         connect.close()
#
# /opt/conda/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1004         """
#    1005         if isinstance(object_, util.string_types[0]):
# -> 1006             return self._execute_text(object_, multiparams, params)
#    1007         try:
#    1008             meth = object_._execute_on_connection
#
# /opt/conda/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1173         dialect = self.dialect
#    1174         parameters = _distill_params(multiparams, params)
# -> 1175         ret = self._execute_context(
#    1176             dialect,
#    1177             dialect.execution_ctx_cls._init_statement,
#
# /opt/conda/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# /opt/conda/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1513                 )
#    1514             else:
# -> 1515                 util.raise_(exc_info[1], with_traceback=exc_info[2])
#    1516
#    1517         finally:
#
# /opt/conda/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /opt/conda/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                             break
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#    1279                     )
#
# /opt/conda/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# /opt/conda/lib/python3.8/site-packages/sqlalchemy_clickhouse/connector.py in execute(self, operation, parameters, is_response)
#     208         if is_response:
#     209             response = self._db.select(sql, settings={'query_id': self._uuid})
# --> 210             self._process_response(response)
#     211         else:
#     212             self._db.raw(sql)
#
# /opt/conda/lib/python3.8/site-packages/sqlalchemy_clickhouse/connector.py in _process_response(self, response)
#     339         cols = None
#     340         data = []
# --> 341         for r in response:
#     342             if not cols:
#     343                 cols = [(f, r._fields[f].db_type) for f in r._fields]
#
# RuntimeError: generator raised StopIteration
